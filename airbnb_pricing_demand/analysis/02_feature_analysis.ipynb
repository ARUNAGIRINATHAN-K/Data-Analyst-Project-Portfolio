# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('/workspaces/Data-Analyst-Project-Portfolio/airbnb_pricing_demand/data/airbnb_listings_cleaned.csv')
print("Data Loaded:", df.shape)
# Out:
# Data Loaded: (120, 13)

# %%
sns.histplot(df['price'], bins=50, kde=True)
plt.title('Distribution of Price')
plt.xlabel('Price ($)')
plt.xlim(0, df['price'].quantile(0.95))  
plt.show()

# %%
numeric_cols = ['price', 'minimum_nights', 'number_of_reviews',
                'review_score', 'availability_365', 'host_years']
correlation = df[numeric_cols].corr()

# %%
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.boxplot(data=df, x='room_type', y='price')
plt.title('Price by Room Type')
plt.ylim(0, df['price'].quantile(0.95))
plt.show()

# %%
top_props = df['property_type'].value_counts().nlargest(6).index
sns.boxplot(data=df[df['property_type'].isin(top_props)],
            x='property_type', y='price')
plt.title('Price by Property Type')
plt.xticks(rotation=45)
plt.ylim(0, df['price'].quantile(0.95))
plt.show()

# %%
sns.scatterplot(data=df, x='number_of_reviews', y='price', alpha=0.4)
plt.title('Number of Reviews vs Price')
plt.xlim(0, df['number_of_reviews'].quantile(0.95))
plt.ylim(0, df['price'].quantile(0.95))
plt.show()

# %%
sns.scatterplot(data=df, x='availability_365', y='price', alpha=0.4)
plt.title('Availability (days/year) vs Price')
plt.show()

# %%
sns.boxplot(data=df, x=pd.cut(df['review_score'], bins=[0, 70, 80, 90, 100]),
            y='price')
plt.title('Price vs Review Score Range')
plt.ylim(0, df['price'].quantile(0.95))
plt.show()

# %%
if df['city'].nunique() > 1:
    sns.boxplot(data=df, x='city', y='price')
    plt.title('City-wise Price Distribution')
    plt.xticks(rotation=45)
    plt.ylim(0, df['price'].quantile(0.95))
    plt.show()
